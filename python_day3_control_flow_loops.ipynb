# %% [markdown]
# ### Question 1
# Print numbers from 1 to 100 using a loop.

# %%
# Write your code here

# %% [markdown]
# ### Question 2
# Print all odd numbers between 1 and 50.

# %%
# Write your code here

# %% [markdown]
# ### Question 3
# Find the sum of first 50 natural numbers.

# %%
# Write your code here

# %% [markdown]
# ### Question 4
# Print the multiplication table of numbers from 1 to 5.

# %%
# Write your code here

# %% [markdown]
# ### Question 5
# Count how many numbers between 1 and 100 are divisible by 3.

# %%
# Write your code here

# %% [markdown]
# ### Question 6
# Print a right-angled triangle pattern using *:
# *
# **
# ***
# ****

# %%
# Write your code here

# %% [markdown]
# ### Question 7
# Print an inverted triangle pattern.

# %%
# Write your code here

# %% [markdown]
# ### Question 8
# Print a pyramid pattern.

# %%
# Write your code here

# %% [markdown]
# ### Question 9
# Find factorial of a number using a loop.

# %%
# Write your code here

# %% [markdown]
# ### Question 10
# Check if a number is palindrome (same forward and backward).

# %%
# Write your code here

# %% [markdown]
# ### Question 11
# Generate Fibonacci series up to n terms.

# %%
# Write your code here

# %% [markdown]
# ### Question 12
# Find the largest number in a list using loop.

# %%
# Write your code here

# %% [markdown]
# ### Question 13
# Count vowels in a given string.

# %%
# Write your code here

# %% [markdown]
# ### Question 14
# Reverse a string using loop.

# %%
# Write your code here

# %% [markdown]
# ### Question 15
# Find the sum of digits of a number.

# %%
# Write your code here

# %% [markdown]
# ### Question 16
# Check if a number is Armstrong number.

# %%
# Write your code here

# %% [markdown]
# ### Question 17
# Print all prime numbers between 1 and 100.

# %%
# Write your code here

# %% [markdown]
# ### Question 18
# Use nested loops to print a multiplication grid (1–5).

# %%
# Write your code here

# %% [markdown]
# ### Question 19
# Simulate a simple login system (3 attempts using loop).

# %%
# Write your code here

# %% [markdown]
# ### Question 20
# Create a number guessing game using loop (user vs fixed number).

# %%
# Write your code here
