# %% [markdown]
# ### Question 1
# Create a tuple with 5 elements and print it.

# %%
# Write your code here

# %% [markdown]
# ### Question 2
# Access the first and last element of a tuple.

# %%
# Write your code here

# %% [markdown]
# ### Question 3
# Try modifying a tuple element. What happens? Explain.

# %%
# Write your code here

# %% [markdown]
# ### Question 4
# Convert a tuple into a list.

# %%
# Write your code here

# %% [markdown]
# ### Question 5
# Count how many times an element appears in a tuple.

# %%
# Write your code here

# %% [markdown]
# ### Question 6
# Find the index of an element in a tuple.

# %%
# Write your code here

# %% [markdown]
# ### Question 7
# Create a tuple with mixed data types.

# %%
# Write your code here

# %% [markdown]
# ### Question 8
# Unpack a tuple into variables.

# %%
# Write your code here

# %% [markdown]
# ### Question 9
# Create a set with some duplicate values and print it.

# %%
# Write your code here

# %% [markdown]
# ### Question 10
# Add an element to a set.

# %%
# Write your code here

# %% [markdown]
# ### Question 11
# Remove an element from a set.

# %%
# Write your code here

# %% [markdown]
# ### Question 12
# Perform union of two sets.

# %%
# Write your code here

# %% [markdown]
# ### Question 13
# Perform intersection of two sets.

# %%
# Write your code here

# %% [markdown]
# ### Question 14
# Find the difference between two sets.

# %%
# Write your code here

# %% [markdown]
# ### Question 15
# Check if an element exists in a set.

# %%
# Write your code here

# %% [markdown]
# ### Question 16
# Convert a list into a set to remove duplicates.

# %%
# Write your code here

# %% [markdown]
# ### Question 17
# Create a dictionary with keys: name, age, city.

# %%
# Write your code here

# %% [markdown]
# ### Question 18
# Access values using keys in a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 19
# Add a new key-value pair to a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 20
# Update a value in a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 21
# Remove a key from a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 22
# Iterate through keys and values in a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 23
# Check if a key exists in a dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Question 24
# Get all keys and all values separately.

# %%
# Write your code here

# %% [markdown]
# ### Question 25
# Create a dictionary from two lists (keys and values).

# %%
# Write your code here

# %% [markdown]
# ### Question 26
# Count frequency of elements in a list using dictionary.

# %%
# Write your code here
