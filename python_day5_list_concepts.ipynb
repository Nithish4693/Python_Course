# %% [markdown]
# ### Question 1
# Create a list of 5 numbers and print it.

# %%
num=[85,54,86]
print(num)
# Out:
# [85, 54, 86]

# %% [markdown]
# ### Question 2
# Access the first and last element of a list.

# %%
num=[2,5,4,8,9]
print(num[0])
print(num[-1])
# Out:
# 2
# 9

# %% [markdown]
# ### Question 3
# Add an element to the end of a list using append().

# %%
number=[8,5,8,7,5]
number.append(0)
print(number)
# Out:
# [8, 5, 8, 7, 5, 0]

# %% [markdown]
# ### Question 4
# Insert an element at a specific position in a list.

# %%
list=[8,5,6,7]
list.insert(0,548)
print(list)
# Out:
# [548, 8, 5, 6, 7]

# %% [markdown]
# ### Question 5
# Remove an element from a list using remove().

# %%
list=[7,5,8,6]
list.remove(7)
print(list)
# Out:
# [5, 8, 6]

# %% [markdown]
# ### Question 6
# Pop the last element from a list and print it.

# %%
list=[8,45,5,3]
list.pop(0)
print(list)
# Out:
# [45, 5, 3]

# %% [markdown]
# ### Question 7
# Create a list of numbers and find its length.

# %%
num=[5,7,44,8]
print(len(num))
# Out:
# 4

# %% [markdown]
# ### Question 8
# Sort a list in ascending and descending order.

# %%
num=[23,25,64,75,79]
num.sort()
print(num)
num.sort(reverse=True)
print(num)
# Out:
# [23, 25, 64, 75, 79]
# [79, 75, 64, 25, 23]

# %% [markdown]
# ### Question 9
# Reverse a list.

# %%
num=[1,4,2,5,7,9,8,55]
print(num[::-1])
# Out:
# [55, 8, 9, 7, 5, 2, 4, 1]

# %% [markdown]
# ### Question 10
# Check if an element exists in a list.

# %%
num=[2,34,53,65]
print(265 in num)
# Out:
# False

# %% [markdown]
# ### Question 11
# Find the maximum and minimum value in a list.

# %%
num=[8,5,7]
max(num)
min(num)
print(max(num))
print(min(num))
# Out:
# 8
# 5

# %% [markdown]
# ### Question 12
# Count how many times a value appears in a list.

# %%
num=[1,2,1,1,1]
result=num.count(1)
print(result)
# Out:
# 4

# %% [markdown]
# ### Question 13
# Create a list of even numbers from 1 to 20 using loop.

# %%
even_list=[]
for i range(1,21):
    if i%2==0:
    even_list.append(i)
print(even_list)
# Out:
#   Cell In[2], line 2
#     for i range(1,21):
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Question 14
# Create a new list with squares of numbers from another list.

# %%
num=[1,4,5,7]
square_list=[]
for i in num:
    square_list.append(i*i)
    print(square_list)
# Out:
# [1]
# [1, 16]
# [1, 16, 25]
# [1, 16, 25, 49]

# %% [markdown]
# ### Question 15
# Merge two lists into one.

# %%
num1=[4,5,8,6,8]
num2=1[7,8,6,5,2]
num=num1+num2
print(num)
# Out:
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# C:\Users\praveena\AppData\Local\Temp\ipykernel_20320\1764186835.py:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   num2=1[7,8,6,5,2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 num1=[4,5,8,6,8]
# ----> 2 num2=1[7,8,6,5,2]
#       3 num=num1+num2
#       4 print(num)
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### Question 16
# Remove duplicates from a list.

# %%
num=[8,8,8,9,5,4,5,6,4,1]
result=list(set(num))
print(result)
# Out:
# [1, 4, 5, 6, 8, 9]

# %% [markdown]
# ### Question 17
# Take a list and print only unique elements.

# %%
nums = [8, 8, 8, 9, 5, 4, 5, 6, 4, 1]

print(list(set(nums)))
# Out:
# [1, 4, 5, 6, 8, 9]

# %% [markdown]
# ### Question 18
# Find the sum of all elements in a list.

# %%
num= [1, 2, 3, 4, 5]

result = sum(num)

print(result)
# Out:
# 15

# %% [markdown]
# ### Question 19
# Iterate through a list and print each element.

# %%
nums = [10, 20, 30, 40, 50]

for i in nums:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# ### Question 20
# Create a nested list and access elements inside it.

# %%
nums = [[10, 20], [30, 40], [50, 60]]

print(nums[0])
print(nums[0][1])
print(nums[1][0])
print(nums[2][1])

for i in nums:
    for j in i:
        print(j)
# Out:
# [10, 20]
# 20
# 30
# 60
# 10
# 20
# 30
# 40
# 50
# 60
