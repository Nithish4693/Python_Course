# %% [markdown]
# ### Question 1
# Create a variable `name` and assign your name. Print it.

# %%
# Write your code here

# %% [markdown]
# ### Question 2
# Store your age in a variable and print: "I am <age> years old"

# %%
# Write your code here

# %% [markdown]
# ### Question 3
# Create two variables `a = 10` and `b = 5`. Print their sum.

# %%
# Write your code here

# %% [markdown]
# ### Question 4
# Assign a float value to a variable and print its type.

# %%
# Write your code here

# %% [markdown]
# ### Question 5
# Create a variable `is_student` and assign a boolean value. Print it.

# %%
# Write your code here

# %% [markdown]
# ### Question 6
# Store a string "Python" in a variable and print its data type.

# %%
# Write your code here

# %% [markdown]
# ### Question 7
# Assign multiple variables in one line: `x, y, z = 1, 2, 3` and print them.

# %%
# Write your code here

# %% [markdown]
# ### Question 8
# Swap two variables without using a third variable.

# %%
# Write your code here

# %% [markdown]
# ### Question 9
# Take a number and convert it into a string. Print both values and their types.

# %%
# Write your code here

# %% [markdown]
# ### Question 10
# Create a variable with a number in string form "100" and convert it to integer.

# %%
# Write your code here

# %% [markdown]
# ### Question 11
# Add an integer and a float, and print the result and its type.

# %%
# Write your code here

# %% [markdown]
# ### Question 12
# Create variables of all basic data types: int, float, str, bool and print their types.

# %%
# Write your code here

# %% [markdown]
# ### Question 13
# Concatenate two strings "Hello" and "World" and print the result.

# %%
# Write your code here

# %% [markdown]
# ### Question 14
# Multiply a string "Hi" by 3 and print the result.

# %%
# Write your code here

# %% [markdown]
# ### Question 15
# Create a variable and check its type using type() function.

# %%
# Write your code here

# %% [markdown]
# ### Question 16
# Create variables a = 10, b = "20". Convert and add them correctly.

# %%
# Write your code here

# %% [markdown]
# ### Question 17
# Check the type of x = 5, y = 5.0, z = "5". Print all types.

# %%
# Write your code here

# %% [markdown]
# ### Question 18
# Assign a boolean value based on a condition: x = 10, y = 20. Check if x < y.

# %%
# Write your code here

# %% [markdown]
# ### Question 19
# Create a variable pi = 3.14 and convert it to an integer. Print both.

# %%
# Write your code here

# %% [markdown]
# ### Question 20
# What will be the output?
# a = "10"
# b = 5
# print(a + str(b))
# Explain why.

# %%
# Write your code here
